# %% [markdown]
# Install dependencies

# %%
# !pip install -U torch torchvision torchaudio transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 55.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 100.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.2 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/neonbjb/tortoise-tts.git
# Out:
# Cloning into 'tortoise-tts'...
# remote: Enumerating objects: 1774, done.
# remote: Counting objects: 100% (1774/1774), done.
# remote: Compressing objects: 100% (1024/1024), done.
# remote: Total 1774 (delta 797), reused 1603 (delta 733), pack-reused 0
# Receiving objects: 100% (1774/1774), 54.11 MiB | 10.98 MiB/s, done.
# Resolving deltas: 100% (797/797), done.

# %%
# !cd tortoise-tts/ && python setup.py install
# Out:
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
# ...

# %% [markdown]
# ##**TODO**
# 1. Add folder george in voices and upload voice files
# 2. Add folder george in /content and add gpt-speech.txt
# 3. Remove dependency tornado==4.2 from requirements.txt

# %%
# !cd tortoise-tts/ && pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 50.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 19.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.2/387.2 kB 38.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 93.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.4/765.4 kB 60.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 35.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 16.1 MB/s eta 0:00:00
# ...
#   Created wheel for deepspeed: filename=deepspeed-0.8.3-py3-none-any.whl size=776398 sha256=d1380c3afceb1e8560a79cb714285589ca2cddccdb1d0b114d924d89d7718ce1
# ...

# %%
# !cd tortoise-tts/tortoise/ && python read.py --textfile /content/george/gpt-speech.txt --voice george --output_path /content/george/generated/ --output_name george_speech --preset fast --seed 42 --use_deepspeed true --kv_cache true --half true
# Out:
# ...
# 100% (1716988501 of 1716988501) |#########| Elapsed Time: 0:00:10 Time:  0:00:10
# Done.
# [2023-09-01 05:55:29,145] [INFO] [logging.py:93:log_dist] [Rank -1] DeepSpeed info: version=0.8.3, git-hash=unknown, git-branch=unknown
# [2023-09-01 05:55:29,146] [WARNING] [config_utils.py:75:_process_deprecated_field] Config parameter mp_size is deprecated use tensor_parallel.tp_size instead
# [2023-09-01 05:55:29,146] [INFO] [logging.py:93:log_dist] [Rank -1] quantize_bits = 8 mlp_extra_grouping = False, quantize_groups = 1
# Using /root/.cache/torch_extensions/py310_cu118 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py310_cu118/transformer_inference...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu118/transformer_inference/build.ninja...
# Building extension module transformer_inference...
# ...

# %%
# !cd tortoise-tts/tortoise/ && python do_tts.py --text "Ladies and gentlemen, distinguished guests, and fellow teck enthusiasts; Today, I'm honored to discuss a game changing technology that's reshaping industries and human potential; Artificial Intelligence." --voice george --output_path /content/george/generated/ --preset fast --seed 42 --use_deepspeed true --kv_cache true --half true
# Out:
# [2023-08-31 18:53:35,802] [INFO] [logging.py:93:log_dist] [Rank -1] DeepSpeed info: version=0.8.3, git-hash=unknown, git-branch=unknown
# [2023-08-31 18:53:35,803] [WARNING] [config_utils.py:75:_process_deprecated_field] Config parameter mp_size is deprecated use tensor_parallel.tp_size instead
# [2023-08-31 18:53:35,803] [INFO] [logging.py:93:log_dist] [Rank -1] quantize_bits = 8 mlp_extra_grouping = False, quantize_groups = 1
# Using /root/.cache/torch_extensions/py310_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu118/transformer_inference/build.ninja...
# Building extension module transformer_inference...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module transformer_inference...
# Time to load transformer_inference op: 0.12692713737487793 seconds
# ...
